# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# ## Loading Datasets

# %%
import pandas as pd
df = pd.read_csv('IPL2013.csv')

# %% [markdown]
# Age - Number of years the player is playing for that team

# %%
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
#list all columns
list(df)
# Out:
# ['Sl.NO.',
#  'PLAYER NAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %%
df.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
str(type(df))
# Out:
# "<class 'pandas.core.frame.DataFrame'>"

# %%
df.shape
# Out:
# (130, 26)

# %%
#data types of all columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %% [markdown]
# ## Indexing

# %%
df[0:5]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df[-5:]
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 125           0      0.00  ...  125.64       2       0     0    0.00  0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00  0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43  7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50  9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df[['PLAYER NAME','AGE']][0:5]
# Out:
#     PLAYER NAME  AGE
# 0   Abdulla, YA    2
# 1  Abdur Razzak    2
# 2   Agarkar, AB    2
# 3     Ashwin, R    1
# 4  Badrinath, S    2

# %%
#values in those rows and columns
df.iloc[4:9,1:4]
# Out:
#      PLAYER NAME  AGE COUNTRY
# 4   Badrinath, S    2     IND
# 5     Bailey, GJ    2     AUS
# 6      Balaji, L    2     IND
# 7  Bollinger, DE    2     AUS
# 8       Botha, J    2      SA

# %% [markdown]
# ## Unique Occurance

# %%
#unique occurance of values in the column
df['COUNTRY'].value_counts()
# Out:
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# ZIM     1
# BAN     1
# Name: COUNTRY, dtype: int64

# %%
#unique occurance of values in the column in %age
df['COUNTRY'].value_counts(normalize=True)*100
# Out:
# IND    40.769231
# AUS    16.923077
# SA     12.307692
# SL      9.230769
# PAK     6.923077
# NZ      5.384615
# WI      4.615385
# ENG     2.307692
# ZIM     0.769231
# BAN     0.769231
# Name: COUNTRY, dtype: float64

# %% [markdown]
# ## Cross Tabulation between 2 columns

# %%
pd.crosstab(df['AGE'],df['PLAYING ROLE'])
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# AGE
# 1                      4        5       7          0
# 2                     25       21      29         11
# 3                      6       13       8          1

# %% [markdown]
# ## Sorting values in a Column

# %%
df[['PLAYER NAME','SOLD PRICE']].sort_values('SOLD PRICE')
# Out:
#        PLAYER NAME  SOLD PRICE
# 73      Noffke, AA       20000
# 46     Kamran Khan       24000
# 0      Abdulla, YA       50000
# 1     Abdur Razzak       50000
# 118  Van der Merwe       50000
# ..             ...         ...
# 113     Tiwary, SS     1600000
# 111  Tendulkar, SR     1800000
# 50        Kohli, V     1800000
# 93       Sehwag, V     1800000
# 127   Yuvraj Singh     1800000
#
# [130 rows x 2 columns]

# %%
df[['PLAYER NAME','SOLD PRICE']].sort_values('SOLD PRICE', ascending = False)[0:5]
# Out:
#        PLAYER NAME  SOLD PRICE
# 93       Sehwag, V     1800000
# 127   Yuvraj Singh     1800000
# 50        Kohli, V     1800000
# 111  Tendulkar, SR     1800000
# 113     Tiwary, SS     1600000

# %% [markdown]
# ## Creating new Column

# %%
df['PREMIUM']=df['SOLD PRICE']-df['BASE PRICE']

# %%
df[['PLAYER NAME','BASE PRICE','SOLD PRICE','PREMIUM']][0:5]
# Out:
#     PLAYER NAME  BASE PRICE  SOLD PRICE  PREMIUM
# 0   Abdulla, YA       50000       50000        0
# 1  Abdur Razzak       50000       50000        0
# 2   Agarkar, AB      200000      350000   150000
# 3     Ashwin, R      100000      850000   750000
# 4  Badrinath, S      100000      800000   700000

# %% [markdown]
# ## Player who got maximum premium

# %%
df[['PLAYER NAME','BASE PRICE','SOLD PRICE','PREMIUM']].sort_values('PREMIUM',ascending=False)[:1]
# Out:
#    PLAYER NAME  BASE PRICE  SOLD PRICE  PREMIUM
# 50    Kohli, V      150000     1800000  1650000

# %% [markdown]
# ## Grouping and Aggregation

# %%
#average sold price for each age category
df.groupby('AGE')['SOLD PRICE'].mean()
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64

# %%
#sort by descending average sold price for each country category
df.groupby('COUNTRY')['SOLD PRICE'].mean().sort_values(ascending=False)
# Out:
# COUNTRY
# ENG    1.066667e+06
# IND    6.523396e+05
# NZ     5.264286e+05
# AUS    4.340909e+05
# SA     4.275000e+05
# SL     4.237500e+05
# PAK    3.305556e+05
# WI     2.791667e+05
# ZIM    1.250000e+05
# BAN    5.000000e+04
# Name: SOLD PRICE, dtype: float64

# %%
#resetting indexes by average sold price
soldprice_by_age=df.groupby('AGE')['SOLD PRICE'].mean().reset_index()
soldprice_by_age
# Out:
#    AGE     SOLD PRICE
# 0    1  720250.000000
# 1    2  484534.883721
# 2    3  520178.571429

# %%
#grouping by age, playing role and then getting avg SP of each
#getting avg SP for different playing roles in each age category
#resetting indexes by average sold price (SP is used and not any other columns as SP has unique values)
#used when the index is meaningless and needs to be reset to the default 
soldprice_by_agerole=df.groupby(['AGE','PLAYING ROLE'])['SOLD PRICE'].mean().reset_index()
soldprice_by_agerole
# Out:
#     AGE PLAYING ROLE    SOLD PRICE
# 0     1   Allrounder  5.875000e+05
# 1     1      Batsman  1.110000e+06
# 2     1       Bowler  5.177143e+05
# 3     2   Allrounder  4.494000e+05
# 4     2      Batsman  6.547619e+05
# 5     2       Bowler  3.979310e+05
# 6     2    W. Keeper  4.677273e+05
# 7     3   Allrounder  7.666667e+05
# 8     3      Batsman  4.576923e+05
# 9     3       Bowler  4.143750e+05
# 10    3    W. Keeper  7.000000e+05

# %% [markdown]
# ## Joining Dataframes

# %%
#compare average auction price for different ages and playing role
#join DFs based on column Age
#taking outer join
soldprice_comparison = soldprice_by_agerole.merge(soldprice_by_age, on = 'AGE', how = 'outer')
soldprice_comparison
# Out:
#     AGE PLAYING ROLE  SOLD PRICE_x   SOLD PRICE_y
# 0     1   Allrounder  5.875000e+05  720250.000000
# 1     1      Batsman  1.110000e+06  720250.000000
# 2     1       Bowler  5.177143e+05  720250.000000
# 3     2   Allrounder  4.494000e+05  484534.883721
# 4     2      Batsman  6.547619e+05  484534.883721
# 5     2       Bowler  3.979310e+05  484534.883721
# 6     2    W. Keeper  4.677273e+05  484534.883721
# 7     3   Allrounder  7.666667e+05  520178.571429
# 8     3      Batsman  4.576923e+05  520178.571429
# 9     3       Bowler  4.143750e+05  520178.571429
# 10    3    W. Keeper  7.000000e+05  520178.571429

# %% [markdown]
# ## Renaming Columns

# %%
soldprice_comparison.rename(columns = {'SOLD PRICE_x':'SOLD PRICE_AGE_ROLE', 'SOLD PRICE_y':'SOLD PRICE_AGE'}, inplace = True)

# %%
soldprice_comparison.head(5)
# Out:
#    AGE PLAYING ROLE  SOLD PRICE_AGE_ROLE  SOLD PRICE_AGE
# 0    1   Allrounder         5.875000e+05   720250.000000
# 1    1      Batsman         1.110000e+06   720250.000000
# 2    1       Bowler         5.177143e+05   720250.000000
# 3    2   Allrounder         4.494000e+05   484534.883721
# 4    2      Batsman         6.547619e+05   484534.883721
